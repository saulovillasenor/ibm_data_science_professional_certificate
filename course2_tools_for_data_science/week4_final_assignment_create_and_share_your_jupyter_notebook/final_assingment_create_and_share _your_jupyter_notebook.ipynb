# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Saulo Adonai Villaseñor Avalos__
#
# I currently work at Tata Consultancy Services as a Production Support Engineer and would like to become a data scientitst.

# %% [markdown]
# _I am interested in data science because it has an incredibly wide range of applications and can be used as a process in other software areas like artificial intelligence._
#
# _I also like discovering things which are apparently hidden by doing exploratory data analysis._

# %% [markdown]
# ### My  program below is very simple and will print "Hello World!", which is usually the first thing a new programmer learns when starting his coding journey.

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# In this last cell I will show how to:
# 1. Create a numbered list
# 2. Like this one
#
# And also how to do:
# - Bulleted lists
# - Like this other one
#
# Also, this is is an hyperlink to the [Markdown Cheatsheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
#
# And let's finish with a table:
#
# |Name|Nationality|Occupation|
# |------|------|------|
# |A. Einstein|German|Theorical Physicist|
# |E. Musk|South African|~~Inventor~~ Businessman|
# |F. Dostoyevsky|Ryussian|Author|
